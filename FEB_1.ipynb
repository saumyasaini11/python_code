# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyasaini11/python_code/blob/main/FEB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str_1='welcome to python'
list_1=[i for i in str_1]
list_2=[i for i in range(20)]
list_3=[i for i in range(20) if i%2==0]
# wap to create a list which displays the nos. with the corresponding even and odd nos.

list_4 = [i for i in range(101)]
for i in list_4:
  if i % 2 == 0:
    print(f'{i} is even')
  else:
    print(f'{i} is odd')

####
num=[1,2,3,4,'five','six']
res=[str(a) for a in num if str(a).isdigit()]
print(res)
res2=[str(a) for a in num if str(a).isalpha()]
print(res2)


#### SETS ####
a={1,2,3,4,5,6}
for i in enumerate(a): #enumerate prints the index value and the value assigned to it
  print(i)
print(list(a)[2:5])
print(list(a)[2]) #index value is 2


'''
b={sapid:500125720
   dept: "socs"
   university: "UPES"}
print(b)'''

#wap to find the largest element in a list
num=[i for i in range(101) ]
x=max(num)
print(x)
# Out:
# 0 is even
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# 11 is odd
# 12 is even
# 13 is odd
# 14 is even
# 15 is odd
# 16 is even
# 17 is odd
# 18 is even
# 19 is odd
# 20 is even
# 21 is odd
# 22 is even
# 23 is odd
# 24 is even
# 25 is odd
# 26 is even
# 27 is odd
# 28 is even
# 29 is odd
# 30 is even
# 31 is odd
# 32 is even
# 33 is odd
# 34 is even
# 35 is odd
# 36 is even
# 37 is odd
# 38 is even
# 39 is odd
# 40 is even
# 41 is odd
# 42 is even
# 43 is odd
# 44 is even
# 45 is odd
# 46 is even
# 47 is odd
# 48 is even
# 49 is odd
# 50 is even
# 51 is odd
# 52 is even
# 53 is odd
# 54 is even
# 55 is odd
# 56 is even
# 57 is odd
# 58 is even
# 59 is odd
# 60 is even
# 61 is odd
# 62 is even
# 63 is odd
# 64 is even
# 65 is odd
# 66 is even
# 67 is odd
# 68 is even
# 69 is odd
# 70 is even
# 71 is odd
# 72 is even
# 73 is odd
# 74 is even
# 75 is odd
# 76 is even
# 77 is odd
# 78 is even
# 79 is odd
# ...
